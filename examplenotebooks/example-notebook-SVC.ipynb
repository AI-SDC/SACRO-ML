# %% [markdown]
# ## A Quick Start Guide to implementing Safer Support Vector Machines

# %%
import os
import sys
import pylab as plt
import numpy as np
import logging
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

from sklearn import datasets

ROOT_DIR = os.path.dirname(os.path.dirname(os.path.abspath("")))
sys.path.append(ROOT_DIR)
logging.basicConfig()
logger = logging.getLogger("wrapper_svm")
logger.setLevel(logging.INFO)
# ROOT_PROJECT_FOLDER = os.path.dirname(os.path.dirname(__file__))
# sys.path.append(ROOT_PROJECT_FOLDER)
from safemodel.classifiers import SafeSVC
# Out:
# 2022-08-16 11:03:31.535146: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-08-16 11:03:31.535293: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ## Use the sklearn Wisconsin breast cancer dataset

# %%
cancer = datasets.load_breast_cancer()
x = np.asarray(cancer.data, dtype=np.float64)
y = np.asarray(cancer.target, dtype=np.float64)

# %% [markdown]
# ## Kernel for approximator: equivalent to rbf.

# %%
def rbf(x, y, gamma=1):
    return np.exp(-gamma * np.sum((x - y) ** 2))


def rbf_svm(x, y, gamma=1):
    r = np.zeros((x.shape[0], y.shape[0]))
    for i in range(x.shape[0]):
        for j in range(y.shape[0]):
            r[i, j] = rbf(x[i, :], y[j, :], gamma)
    return r

# %% [markdown]
# ## Set parameters

# %%
gamma = 0.1  # Kernel width
C = 1  # Penalty term
dhat = 5  # Dimension of approximator
eps = 500  # DP level (not very private)

# %% [markdown]
# # Define Differentially Private version with DP level (approximate)

# %%
clf3 = SafeSVC(eps=eps, dhat=dhat, C=C, gamma=gamma)
clf3.fit(x, y)
c3 = clf3.predict(x)
p3 = clf3.predict_proba(x)

# %%
clf3 = SafeSVC(eps=eps, dhat=dhat, C=C, gamma=gamma)
clf3.fit(x, y)
clf3.save(name="testSaveSVC.pkl")
clf3.request_release(filename="testSaveSVC.pkl")

# %%
# !echo "contents of checkfile are"; cat *_check*ile.json
# Out:
# contents of checkfile are
# {
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted\n"
# }{
#     "researcher": "andy",
#     "model_type": "SVC",
#     "model_save_file": "testSaveSVC.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 2 places:\nparameter svc changed from SVC(kernel='precomputed') to SVC(kernel='precomputed') after model was fitted\nparameter platt_transform changed from LogisticRegression() to LogisticRegression() after model was fitted\n"
# }{
#     "researcher": "andy",
#     "model_type": "SVC",
#     "model_save_file": "testSaveSVC.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 2 places:\nparameter svc changed from SVC(kernel='precomputed') to SVC(kernel='precomputed') after model was fitted\nparameter platt_transform changed from LogisticRegression() to LogisticRegression() after model was fitted\n"
# }{
#     "researcher": "andy",
#     "model_type": "SVC",
#     "model_save_file": "testSaveSVC.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 2 places:\nparameter svc changed from SVC(kernel='precomputed') to SVC(kernel='precomputed') after model was fitted\nparameter platt_transform changed from LogisticRegression() to LogisticRegression() after model was fitted\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted\n"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "unsafe1.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter bootstrap = False identified as different than the recommended fixed value of True.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter bootstrap = False identified as different than the recommended fixed value of True."
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "unsafe2.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 2 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 2 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "unsafe3.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter bootstrap = False identified as different than the recommended fixed value of True.- parameter min_samples_leaf = 2 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter bootstrap = False identified as different than the recommended fixed value of True.- parameter min_samples_leaf = 2 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "unsafe4.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter bootstrap = False identified as different than the recommended fixed value of True.- parameter min_samples_leaf = 2 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter bootstrap = False identified as different than the recommended fixed value of True.- parameter min_samples_leaf = 2 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "SVC",
#     "model_save_file": "testSaveSVC.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 2 places:\nparameter svc changed from SVC(kernel='precomputed') to SVC(kernel='precomputed') after model was fitted\nparameter platt_transform changed from LogisticRegression() to LogisticRegression() after model was fitted\n"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fca8d8af9a0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fca8d8af9a0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f3225549bb0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f3225549bb0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7faa6dcb8e80> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7faa6dcb8e80> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7faa6dcb8e80> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7faa6dcb8e80> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7ff2b7d2d820> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7ff2b7d2d820> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7ff2b7d2d820> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7ff2b7d2d820> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fa6d7b2cbb0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fa6d7b2cbb0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fa6d7b2cbb0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fa6d7b2cbb0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fab01820b50> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fab01820b50> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fab01820b50> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fab01820b50> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f1da26b2af0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f1da26b2af0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f1da26b2af0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f1da26b2af0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7ffa0d4e0fa0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7ffa0d4e0fa0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7ffa0d4e0fa0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7ffa0d4e0fa0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fee92cfbf70> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fee92cfbf70> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fee92cfbf70> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fee92cfbf70> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fb518bf0910> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fb518bf0910> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fb518bf0910> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fb518bf0910> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f3bb84c2fa0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f3bb84c2fa0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f3bb84c2fa0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f3bb84c2fa0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f876871dd30> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f876871dd30> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f876871dd30> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f876871dd30> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f1b8f59e700> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f1b8f59e700> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f1b8f59e700> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f1b8f59e700> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f833da03d30> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f833da03d30> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f833da03d30> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f833da03d30> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f516406dd00> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f516406dd00> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f516406dd00> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7f516406dd00> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fccdb3ada30> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fccdb3ada30> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fccdb3ada30> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fccdb3ada30> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fcce4237850> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fcce4237850> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fb57c145cd0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fb57c145cd0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fb57c145cd0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fb57c145cd0> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fb55fb40430> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter optimizer = <tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass object at 0x7fb55fb40430> identified as different type to recommendation of tensorflow_privacy.privacy.optimizers.dp_optimizer_keras.make_keras_optimizer_class.<locals>.DPOptimizerClass.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.True"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
# ...
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nError: user has not called fit() method or has deleted saved values.Recommendation: Do not release. The model will be DP because  value of optimizer._was_dp_gradients_called is True so DP variant of optimizer has been run; however, epsilon is not sufficient for Differential privacy: 95.01485486178547. You must modify one or more of batch_size, epochs, number of samples."
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nError: user has not called fit() method or has deleted saved values.Recommendation: Do not release. The model will be DP because  value of optimizer._was_dp_gradients_called is True so DP variant of optimizer has been run; however, epsilon is not sufficient for Differential privacy: 95.01485486178547. You must modify one or more of batch_size, epochs, number of samples."
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nError: user has not called fit() method or has deleted saved values.Recommendation: Do not release. The model will be DP because  value of optimizer._was_dp_gradients_called is True so DP variant of optimizer has been run; however, epsilon is not sufficient for Differential privacy: 95.01485486178547. You must modify one or more of batch_size, epochs, number of samples."
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nError: user has not called fit() method or has deleted saved values.Recommendation: Do not release. The model will be DP because  value of optimizer._was_dp_gradients_called is True so DP variant of optimizer has been run; however, epsilon is not sufficient for Differential privacy: 95.01485486178547. You must modify one or more of batch_size, epochs, number of samples."
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "None",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nError: user has not called fit() method or has deleted saved values.Recommendation: Do not release. The model will be DP because  value of optimizer._was_dp_gradients_called is True so DP variant of optimizer has been run; however, epsilon is not sufficient for Differential privacy: 23.09099569905857. You must modify one or more of batch_size, epochs, number of samples."
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: at least one non-matching value for parameter list estimators_.\nWarning: at least one non-matching value for parameter list estimators_.\n"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: at least one non-matching value for parameter list estimators_.\nWarning: at least one non-matching value for parameter list estimators_.\n"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: at least one non-matching value for parameter list estimators_.\nWarning: at least one non-matching value for parameter list estimators_.\n"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: at least one non-matching value for parameter list estimators_.\nWarning: at least one non-matching value for parameter list estimators_.\n"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: at least one non-matching value for parameter list estimators_.\nWarning: at least one non-matching value for parameter list estimators_.\n",
#     "timestamp": "Wed Dec  4 00:00:00 2002"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: at least one non-matching value for parameter list estimators_.\nWarning: at least one non-matching value for parameter list estimators_.\n",
#     "timestamp": "Wed Dec  4 00:00:00 2002"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: at least one non-matching value for parameter list estimators_.\nWarning: at least one non-matching value for parameter list estimators_.\n",
#     "timestamp": "00:00:00"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: at least one non-matching value for parameter list estimators_.\nWarning: at least one non-matching value for parameter list estimators_.\n",
#     "timestamp": "00:00:00"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: at least one non-matching value for parameter list estimators_.\nWarning: at least one non-matching value for parameter list estimators_.\n",
#     "timestamp": "2022-08-15 16:01:52"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: at least one non-matching value for parameter list estimators_.\nWarning: at least one non-matching value for parameter list estimators_.\n",
#     "timestamp": "2022-08-15 16:01:53"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWARNING: epsilon 20.618388531874267 is above normal max recommended value.\nDiscussion with researcher needed.\n",
#     "timestamp": "2022-08-16 03:42:25"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWARNING: epsilon 20.618388531874267 is above normal max recommended value.\nDiscussion with researcher needed.\n",
#     "timestamp": "2022-08-16 04:21:58"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWARNING: epsilon 23.09099569905857 is above normal max recommended value.\nDiscussion with researcher needed.\n",
#     "timestamp": "2022-08-16 04:22:27"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter l2_norm_clip = 1.1 identified as greater than the recommended max value of 1.0.- parameter noise_multiplier = 0.6 identified as less than the recommended min value of 0.7.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter l2_norm_clip = 1.1 identified as greater than the recommended max value of 1.0.- parameter noise_multiplier = 0.6 identified as less than the recommended min value of 0.7.WARNING: epsilon 32.860767694468635 is above normal max recommended value.\nDiscussion with researcher needed.\n",
#     "timestamp": "2022-08-16 04:22:42"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWARNING: epsilon 23.09099569905857 is above normal max recommended value.\nDiscussion with researcher needed.\n",
#     "timestamp": "2022-08-16 04:22:54"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWARNING: epsilon 23.09099569905857 is above normal max recommended value.\nDiscussion with researcher needed.\n",
#     "timestamp": "2022-08-16 04:23:08"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWARNING: epsilon 23.09099569905857 is above normal max recommended value.\nDiscussion with researcher needed.\n",
#     "timestamp": "2022-08-16 04:23:21"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWARNING: epsilon 23.09099569905857 is above normal max recommended value.\nDiscussion with researcher needed.\n",
#     "timestamp": "2022-08-16 04:23:36"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWARNING: epsilon 23.09099569905857 is above normal max recommended value.\nDiscussion with researcher needed.\n",
#     "timestamp": "2022-08-16 04:23:52"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file unsafe9.hd5 through next step of checking procedure",
#     "timestamp": "2022-08-16 04:25:10"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file unsafe10.hd5 through next step of checking procedure",
#     "timestamp": "2022-08-16 04:26:37"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe1.h5 through next step of checking procedure",
#     "timestamp": "2022-08-16 04:29:40"
# }{
#     "researcher": "andy",
#     "model_type": "SVC",
#     "model_save_file": "testSaveSVC.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 2 places:\nparameter svc changed from SVC(kernel='precomputed') to SVC(kernel='precomputed') after model was fitted.\nparameter platt_transform changed from LogisticRegression() to LogisticRegression() after model was fitted.\n",
#     "timestamp": "2022-08-16 04:37:25"
# }{
#     "researcher": "andy",
#     "model_type": "SVC",
#     "model_save_file": "testSaveSVC.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter gamma = 6.395533747973492e-07 identified as less than the recommended min value of 0.1.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter gamma = 6.395533747973492e-07 identified as less than the recommended min value of 0.1.Warning: basic parameters differ in 2 places:\nparameter svc changed from SVC(kernel='precomputed') to SVC(kernel='precomputed') after model was fitted.\nparameter platt_transform changed from LogisticRegression() to LogisticRegression() after model was fitted.\n",
#     "timestamp": "2022-08-16 04:58:56"
# }{
#     "researcher": "andy",
#     "model_type": "SVC",
#     "model_save_file": "testSaveSVC.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter gamma = 6.395533747973492e-07 identified as less than the recommended min value of 0.1.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter gamma = 6.395533747973492e-07 identified as less than the recommended min value of 0.1.Warning: basic parameters differ in 2 places:\nparameter svc changed from SVC(kernel='precomputed') to SVC(kernel='precomputed') after model was fitted.\nparameter platt_transform changed from LogisticRegression() to LogisticRegression() after model was fitted.\n",
#     "timestamp": "2022-08-16 11:03:41"
# }
