# %% [markdown]
# # Safe Random Forest Notebook
# ### First set some path variables: this notebook expects to find the repository root in your home directory. You can change this by editing the last sys.path.append line to reflect with the repository root is found on your system

# %%
import sys
import os

from os.path import expanduser

ROOT_DIR = os.path.dirname(os.path.dirname(os.path.abspath("")))
sys.path.append(ROOT_DIR)
home = expanduser("~")
sys.path.append(os.path.abspath(home+'/AI-SDC'))

# %% [markdown]
# ## A Quick Start Guide to implementing Safer Random Forests
#
# ### Lets start by making some data with one disclosive case
# - We'll do this by adding an example to the iris data and give it a new class to make things really obvious.
# - The same risks exist for more complex data sets but _everyone knows iris_

# %%
import numpy as np
from sklearn import datasets

iris = datasets.load_iris()
X = iris.data
y = iris.target


# print the max and min values in each feature to help hand-craft the disclosive point
for feature in range(4):
    print(f"feature {feature} min {np.min(X[:,feature])}, min {np.max(X[:,feature])}")

# now add a single disclosve point with features [7,2,4.5,1] and label 3
X = np.vstack([X, (7, 2.0, 4.5, 1)])
y = np.append(y, 4)
# Out:
# feature 0 min 4.3, min 7.9
# feature 1 min 2.0, min 4.4
# feature 2 min 1.0, min 6.9
# feature 3 min 0.1, min 2.5

# %% [markdown]
# ## Some basic Libraries for visualization

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %% [markdown]
# ## Defining a new class SafeRandomForestClassifier¶
# -Don't forget to import the SafeModel classes.

# %%
from safemodel.safemodel import SafeModel
from safemodel.classifiers import SafeRandomForestClassifier
# Out:
# 2022-09-01 15:03:42.558172: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-09-01 15:03:42.558249: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
safeRFModel = SafeRandomForestClassifier(n_estimators=100)  # (criterion="entropy")

safeRFModel.fit(X, y)

print(f"Training set accuracy in this safe case is {safeRFModel.score(X,y)}")
fig, ax = plt.subplots(10, 10, figsize=(15, 15))
for row in range(10):
    for column in range(10):
        whichTree = 10 * row + column
        treeRowCol = safeRFModel.estimators_[whichTree]
        _ = plot_tree(treeRowCol, filled=True, ax=ax[row][column], fontsize=1)
# Out:
# WARNING: model parameters may present a disclosure risk:
# - parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.
# Changed parameter min_samples_leaf = 5.
#
# Training set accuracy in this safe case is 0.9602649006622517

# %% [markdown]
# ## Using the save and reporting functionality¶

# %%
safeRFModel.save(name="testSaveRF.pkl")
safeRFModel.preliminary_check()
safeRFModel.request_release("testSaveRF.pkl")
# Out:
# Model parameters are within recommended ranges.

# %% [markdown]
# ## The checkfile reports any warnings and reccomendations in JSON format

# %%
# !echo "contents of checkfile are"; cat *_check*ile.json
# Out:
# contents of checkfile are
# {
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure",
#     "timestamp": "2022-08-17 04:09:26"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure",
#     "timestamp": "2022-08-17 04:09:27"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe1.h5 through next step of checking procedure",
#     "timestamp": "2022-08-25 07:04:52"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe1.h5 through next step of checking procedure",
#     "timestamp": "2022-08-25 07:12:40"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe1.h5 through next step of checking procedure",
#     "timestamp": "2022-08-25 07:26:00"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe1.h5 through next step of checking procedure",
#     "timestamp": "2022-08-25 07:44:37"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe1.h5 through next step of checking procedure",
#     "timestamp": "2022-08-25 07:46:32"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe1.h5 through next step of checking procedure",
#     "timestamp": "2022-08-25 07:58:14"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 06:49:07"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 06:49:08"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 06:49:08"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 06:49:08"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.",
#     "timestamp": "2022-08-26 06:49:08"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 06:49:08"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n",
#     "timestamp": "2022-08-26 06:49:08"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe1.h5 through next step of checking procedure",
#     "timestamp": "2022-08-26 06:52:31"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 06:54:35"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 06:54:35"
# }{
#     "researcher": "andy",
#     "model_type": "SVC",
#     "model_save_file": "testSaveSVC.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter gamma = 6.395533747973492e-07 identified as less than the recommended min value of 0.1.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter gamma = 6.395533747973492e-07 identified as less than the recommended min value of 0.1.Warning: basic parameters differ in 2 places:\nparameter svc changed from SVC(kernel='precomputed') to SVC(kernel='precomputed') after model was fitted.\nparameter platt_transform changed from LogisticRegression() to LogisticRegression() after model was fitted.\n",
#     "timestamp": "2022-08-26 06:56:29"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe1.h5 through next step of checking procedure",
#     "timestamp": "2022-08-26 06:58:39"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 07:00:25"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 07:00:26"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 07:00:26"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 07:00:26"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.",
#     "timestamp": "2022-08-26 07:00:26"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 07:00:26"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n",
#     "timestamp": "2022-08-26 07:00:26"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 07:02:16"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 07:02:16"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in {len(match)} places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in {len(match)} places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in {len(match)} places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in {len(match)} places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in {len(match)} places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in {len(match)} places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe1.h5 through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
# ...
#     "timestamp": "2022-09-01 14:37:30"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.",
#     "timestamp": "2022-09-01 14:37:30"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:37:30"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n",
#     "timestamp": "2022-09-01 14:37:30"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:38:03"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:38:04"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:38:04"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:38:04"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.",
#     "timestamp": "2022-09-01 14:38:04"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:38:04"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n",
#     "timestamp": "2022-09-01 14:38:04"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:39:51"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:39:52"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:39:52"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:39:52"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.",
#     "timestamp": "2022-09-01 14:39:52"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:39:52"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n",
#     "timestamp": "2022-09-01 14:39:52"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "timestamp": "2022-09-01 14:48:15"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "timestamp": "2022-09-01 14:50:16"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:50:59"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:51:00"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "timestamp": "2022-09-01 14:51:01"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:51:02"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:51:02"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:51:02"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.",
#     "timestamp": "2022-09-01 14:51:02"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:51:02"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n",
#     "timestamp": "2022-09-01 14:51:02"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:56:35"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:56:36"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "timestamp": "2022-09-01 14:56:36"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:56:37"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:56:37"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:56:37"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.",
#     "timestamp": "2022-09-01 14:56:37"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:56:37"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n",
#     "timestamp": "2022-09-01 14:56:37"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe1.h5 through next step of checking procedure",
#     "timestamp": "2022-09-01 15:02:16"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 15:04:57"
# }

# %% [markdown]
# ## Putting it all together
# -Don't forget to import the SafeModel classes.

# %%
from safemodel.safemodel import SafeModel
from safemodel.classifiers import SafeRandomForestClassifier

safeRFModel = SafeRandomForestClassifier(n_estimators=100)  # (criterion="entropy")
safeRFModel.fit(X, y)
safeRFModel.save(name="testSaveRF.pkl")
safeRFModel.preliminary_check()
safeRFModel.request_release("testSaveRF.pkl")
# Out:
# WARNING: model parameters may present a disclosure risk:
# - parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.
# Changed parameter min_samples_leaf = 5.
#
# Model parameters are within recommended ranges.

# %% [markdown]
# ## Examine the checkfile contents

# %%
# !echo "contents of checkfile are"; cat *_check*ile.json
# Out:
# contents of checkfile are
# {
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure",
#     "timestamp": "2022-08-17 04:09:26"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure",
#     "timestamp": "2022-08-17 04:09:27"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe1.h5 through next step of checking procedure",
#     "timestamp": "2022-08-25 07:04:52"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe1.h5 through next step of checking procedure",
#     "timestamp": "2022-08-25 07:12:40"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe1.h5 through next step of checking procedure",
#     "timestamp": "2022-08-25 07:26:00"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe1.h5 through next step of checking procedure",
#     "timestamp": "2022-08-25 07:44:37"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe1.h5 through next step of checking procedure",
#     "timestamp": "2022-08-25 07:46:32"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe1.h5 through next step of checking procedure",
#     "timestamp": "2022-08-25 07:58:14"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 06:49:07"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 06:49:08"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 06:49:08"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 06:49:08"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.",
#     "timestamp": "2022-08-26 06:49:08"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 06:49:08"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n",
#     "timestamp": "2022-08-26 06:49:08"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe1.h5 through next step of checking procedure",
#     "timestamp": "2022-08-26 06:52:31"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 06:54:35"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 06:54:35"
# }{
#     "researcher": "andy",
#     "model_type": "SVC",
#     "model_save_file": "testSaveSVC.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter gamma = 6.395533747973492e-07 identified as less than the recommended min value of 0.1.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter gamma = 6.395533747973492e-07 identified as less than the recommended min value of 0.1.Warning: basic parameters differ in 2 places:\nparameter svc changed from SVC(kernel='precomputed') to SVC(kernel='precomputed') after model was fitted.\nparameter platt_transform changed from LogisticRegression() to LogisticRegression() after model was fitted.\n",
#     "timestamp": "2022-08-26 06:56:29"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe1.h5 through next step of checking procedure",
#     "timestamp": "2022-08-26 06:58:39"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 07:00:25"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 07:00:26"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 07:00:26"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 07:00:26"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.",
#     "timestamp": "2022-08-26 07:00:26"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 07:00:26"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n",
#     "timestamp": "2022-08-26 07:00:26"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 07:02:16"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure",
#     "timestamp": "2022-08-26 07:02:16"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in {len(match)} places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in {len(match)} places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in {len(match)} places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in {len(match)} places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in {len(match)} places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release."
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in {len(match)} places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe1.h5 through next step of checking procedure"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
# ...
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.",
#     "timestamp": "2022-09-01 14:37:30"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:37:30"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n",
#     "timestamp": "2022-09-01 14:37:30"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:38:03"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:38:04"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:38:04"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:38:04"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.",
#     "timestamp": "2022-09-01 14:38:04"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:38:04"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n",
#     "timestamp": "2022-09-01 14:38:04"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:39:51"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:39:52"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:39:52"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:39:52"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.",
#     "timestamp": "2022-09-01 14:39:52"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:39:52"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n",
#     "timestamp": "2022-09-01 14:39:52"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "timestamp": "2022-09-01 14:48:15"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "timestamp": "2022-09-01 14:50:16"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:50:59"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:51:00"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "timestamp": "2022-09-01 14:51:01"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:51:02"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:51:02"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:51:02"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.",
#     "timestamp": "2022-09-01 14:51:02"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:51:02"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n",
#     "timestamp": "2022-09-01 14:51:02"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:56:35"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file testSave.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:56:36"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "testSave.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "timestamp": "2022-09-01 14:56:36"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe2.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe2.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:56:37"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe3.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file safe3.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:56:37"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "safe4.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "11",
#     "recommendation": "Run file safe4.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:56:37"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "unsafe.pkl",
#     "details": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.",
#     "recommendation": "Do not allow release",
#     "reason": "WARNING: model parameters may present a disclosure risk:\n- parameter min_samples_leaf = 1 identified as less than the recommended min value of 5.Error: user has not called fit() method or has deleted saved values.Recommendation: Do not release.",
#     "timestamp": "2022-09-01 14:56:37"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "fixed-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "5",
#     "recommendation": "Run file fixed-unsafe.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 14:56:37"
# }{
#     "researcher": "andy",
#     "model_type": "DecisionTreeClassifier",
#     "model_save_file": "hacked-unsafe.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Do not allow release",
#     "reason": "Model parameters are within recommended ranges.\nWarning: basic parameters differ in 1 places:\nparameter min_samples_leaf changed from 1 to 5 after model was fitted.\n",
#     "timestamp": "2022-09-01 14:56:37"
# }{
#     "researcher": "andy",
#     "model_type": "KerasModel",
#     "model_save_file": "tfsaves/requested_model.tf",
#     "details": "Model parameters are within recommended ranges.\n",
#     "recommendation": "Run file safe1.h5 through next step of checking procedure",
#     "timestamp": "2022-09-01 15:02:16"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 15:04:57"
# }{
#     "researcher": "andy",
#     "model_type": "RandomForestClassifier",
#     "model_save_file": "testSaveRF.pkl",
#     "details": "Model parameters are within recommended ranges.\n",
#     "k_anonymity": "1",
#     "recommendation": "Run file testSaveRF.pkl through next step of checking procedure",
#     "timestamp": "2022-09-01 15:04:58"
# }
